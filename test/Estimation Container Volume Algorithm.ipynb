# %%
import cv2
import numpy as np

#using matplotlib
from matplotlib import pyplot as plt
from decimal import getcontext, Decimal

# %%
#Author : Lasida Azis
#Version : 0.0.1

class VolumeEstimation:
    path = ""
    raw = ""
    colorspace = ""  
    binary = ""
   
    img = ""
    result = ""
    capacity = 0
    
    def __init__(self, path ):
        print( "Path : " + path)
        self.path = path
        self.estimate()
    
    def estimate( self ):
        raw = cv2.imread( self.path ) #reading image from path
        self.img = cv2.imread( self.path )
        #Convert Color Space
        self.colorspace = cv2.cvtColor(raw, cv2.COLOR_RGB2GRAY)
        
        #convert binary threshold
        _, self.binary = cv2.threshold(self.colorspace, 30, 255, cv2.THRESH_BINARY_INV)
    
#     def adaptiveThreshold():
#         # How Adaptive Threshold Works ?
#         # th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,1)
        
#     def findCountours():
#         #How Countours Works ?
#         contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
#         #draw all contours
#         cntr = cv2.drawContours(image, contours, -1, (255, 255, 0), 2)

    def calculateBlackPixel( self ) :
        #totalpixel = size.panjang * size.tinggi
        totalPixel = binary.shape[0] * binary.shape[1]
        blackPixel = totalPixel - cv2.countNonZero(binary);
        temp = Decimal(blackpixel/total * 100)
        self.result = round( temp, 0 )
        
#     def getROI():
#     def calcBasedPixel():
#     def calcBasedHSVColorSpace():

#     def savedEstimation():
        #Estimated Saving
        
    def set_text( self ):
        cv2.putText(self.img, "{}{}{}".format('Kapasitas : ', 70, '%'), (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    def show_plot( self ):
        titles = ['Color Space','Adaptive Threshold', 'Hasil']
        images = [self.colorspace, self.binary, self.img]

        for i in range(3):
            plt.subplot(1, 3, i+1)
            plt.imshow(images[i] )
            plt.title(titles[i])
            # plt.xticks([]) #remove grid level x
            # plt.yticks([]) #remove grix level y
            plt.show()

# %%
#InstanceProcessing
obj = VolumeEstimation( "proto.jpg" )
obj.set_text()
obj.show_plot()
# Out:
# Path : proto.jpg

# %%
# #Calculate Total Empty Container
# Ex : 
#     p : 3300mm
#     t : 1200mm
#     l : 1800mm
# volume = p x l x t = 3300 * 1200 * 1800 = 7128000000mm3
# volume m = 7.128m3

# #Pecah Panjang Menjadi Grid
# jadi 1 Kotak 
#     p : 330mm/ 33cm = 10 Grid
#     l : 120mm/ 12cm = 10 Grid
#     t : 180mm/ 18cm = 10 Grid
        
#     10 Panjang, 10 Atas, 10 Lebar
        
#     ----------------------------------
#     |                                |
#     |                                |
#     |                                | 12cm
#     |                                |
#     |                                |
#     |                                |
#     ----------------------------------\
#                    33cm                \
#                                         \
#                                          \
#                       |||__|__|__|__|__|
#                       |||__|__|__|__|__|
#                       |||__|__|__|__|__|
#                       |||__|__|__|__|__|
#                       ||/__/__/__/__/__/
#                       |/__/__/__/__/__/
#                       /__/__/__/__/__/
#                      /__/__/__/__/__/
